# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Conjunto de Dados Tips

# %%
df = sns.load_dataset('tips')

# %%
df
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %% [markdown]
# ## Dicionario dos Dados

# %%
df_dict = pd.DataFrame([
    {
        "variavel": "total_bill",
        "descricao": "total de gorjetas",
        "tipo": "quantitativo",
        "subtipo": "continua",
    },{
        "variavel": "tip",
        "descricao": "",
        "tipo": "quantitativo",
        "subtipo": "",
    },{
        "variavel": "sex",
        "descricao": "Sexo do Cliente ('Male','Female')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "smoker",
        "descricao": "Se o cliente era fumante",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "day",
        "descricao": "Dia da Semana da Festa",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "time",
        "descricao": "Hora do dia da Festa",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel": "size",
        "descricao": "Tamanho da Festa",
        "tipo": "quantitativa",
        "subtipo": "discreta",
    }
])

df_dict
# Out:
#      variavel                          descricao          tipo   subtipo
# 0  total_bill                  total de gorjetas  quantitativo  continua
# 1         tip                                     quantitativo
# 2         sex  Sexo do Cliente ('Male','Female')   qualitativa   nominal
# 3      smoker           Se o cliente era fumante   qualitativa   nominal
# 4         day             Dia da Semana da Festa   qualitativa   nominal
# 5        time               Hora do dia da Festa   qualitativa   ordinal
# 6        size                   Tamanho da Festa  quantitativa  discreta

# %% [markdown]
# ## Estatistica dos Dados

# %% [markdown]
# ### Variaveis Qualitativas

# %%
df[['sex', 'smoker', 'day', 'time']].mode()
# Out:
#     sex smoker  day    time
# 0  Male     No  Sat  Dinner

# %% [markdown]
# ### Variaveis Quantitativas

# %%
quantitative_vars = ['total_bill','tip','size']

media = df[quantitative_vars].mean()
mediana = df[quantitative_vars].min()
desvio_padrao = df[quantitative_vars].std()

print("Média:")
print(media)
print("")

print("Mediana:")
print(mediana)
print("")

print("Desvio Padrão:")
print(desvio_padrao)
# Out:
# Média:
# total_bill    19.785943
# tip            2.998279
# size           2.569672
# dtype: float64
#
# Mediana:
# total_bill    3.07
# tip           1.00
# size          1.00
# dtype: float64
#
# Desvio Padrão:
# total_bill    8.902412
# tip           1.383638
# size          0.951100
# dtype: float64

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Calculo Estatistico para cada variavel categórica

# %%
qualitative_vars = ['sex', 'smoker', 'day', 'time']

for variavel in qualitative_vars:
    valores_unicos = df[variavel].unique()
    for valor in valores_unicos:
        print(f"{variavel} - {valor}")
        subamostra = df[df[variavel] == valor]
        display(subamostra.describe())
        print("="*100)
# Out:
# sex - Female
#        total_bill        tip       size
# count   87.000000  87.000000  87.000000
# mean    18.056897   2.833448   2.459770
# std      8.009209   1.159495   0.937644
# min      3.070000   1.000000   1.000000
# 25%     12.750000   2.000000   2.000000
# 50%     16.400000   2.750000   2.000000
# 75%     21.520000   3.500000   3.000000
# max     44.300000   6.500000   6.000000
# ...
# sex - Male
#        total_bill         tip        size
# count  157.000000  157.000000  157.000000
# mean    20.744076    3.089618    2.630573
# std      9.246469    1.489102    0.955997
# min      7.250000    1.000000    1.000000
# 25%     14.000000    2.000000    2.000000
# 50%     18.350000    3.000000    2.000000
# 75%     24.710000    3.760000    3.000000
# max     50.810000   10.000000    6.000000
# ...
# smoker - No
#        total_bill         tip        size
# count  151.000000  151.000000  151.000000
# mean    19.188278    2.991854    2.668874
# std      8.255582    1.377190    1.017984
# ...

# %% [markdown]
# # Cnjunto de Dados Titanic

# %%
df1 = sns.load_dataset('titanic')

# %%
df1
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %% [markdown]
# ## Dicionario dos Dados

# %%
df1_dict = pd.DataFrame([
    {
        "variavel": "survived",
        "descricao": "Sobrevicência ('0=Não','1=Sim')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "pclass",
        "descricao": "Proxy de Classe de Embarque ('1=Superior','2=Médio','3=Inferior')",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel": "sex",
        "descricao": "Sexo do Passageiro ('Male','Female')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "age",
        "descricao": "Idade em Anos",
        "tipo": "quantitativa",
        "subtipo": "discreta",
    },{
        "variavel": "sibsp",
        "descricao": "Número de irmãos/cônjuges a bordo do Titanic",
        "tipo": "quantitativa",
        "subtipo": "discreta",
    },{
        "variavel": "parch",
        "descricao": "Número de pais/filhos a bordo do Titanic",
        "tipo": "quantitativa",
        "subtipo": "discreta",
    },{
        "variavel": "fare",
        "descricao": "Número do Bilhete",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "embarked",
        "descricao": "Proxy de Porto de Embarcação ('C=Cherbourg', 'Q=Queenstown', 'S=Southampton')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "class",
        "descricao": "Classe de Embarque ('First','Second','Third')",
        "tipo": "qualitativa",
        "subtipo": "ordinal",
    },{
        "variavel": "who",
        "descricao": "Genero ('Man','Woman')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "adult_male",
        "descricao": "Homem Adulto ('True','False')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "deck",
        "descricao": "Cabine ('NaN','C','B')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "embark_town",
        "descricao": "Porto de Embarcação ('Cherbourg','Queenstown', 'Southampton')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "alive",
        "descricao": "Atestado de Obito ('yes','no')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    },{
        "variavel": "alone",
        "descricao": "Acompanhante ('True','False')",
        "tipo": "qualitativa",
        "subtipo": "nominal",
    }
])

df1_dict
# Out:
#        variavel                                          descricao  \
# 0      survived                    Sobrevicência ('0=Não','1=Sim')
# 1        pclass  Proxy de Classe de Embarque ('1=Superior','2=M...
# 2           sex               Sexo do Passageiro ('Male','Female')
# 3           age                                      Idade em Anos
# 4         sibsp       Número de irmãos/cônjuges a bordo do Titanic
# 5         parch           Número de pais/filhos a bordo do Titanic
# 6          fare                                  Número do Bilhete
# 7      embarked  Proxy de Porto de Embarcação ('C=Cherbourg', '...
# 8         class      Classe de Embarque ('First','Second','Third')
# 9           who                             Genero ('Man','Woman')
# 10   adult_male                      Homem Adulto ('True','False')
# 11         deck                             Cabine ('NaN','C','B')
# 12  embark_town  Porto de Embarcação ('Cherbourg','Queenstown',...
# ...

# %% [markdown]
# ## Estatistica dos Dados

# %% [markdown]
# ### Variaveis Qualitativas

# %%
df1[['survived',
 'pclass',
 'sex',
 'fare',
 'embarked',
 'class',
 'who',
 'adult_male',
 'deck',
 'embark_town',
 'alive',
 'alone']].mode()
# Out:
#    survived  pclass   sex  fare embarked  class  who  adult_male deck  \
# 0         0       3  male  8.05        S  Third  man        True    C
#
#    embark_town alive  alone
# 0  Southampton    no   True

# %% [markdown]
# ### Variaveis Quantitativas

# %%
df1.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# ### Calculo Estatistico para cada variavel categórica

# %%
qualitative_vars = ['survived',
 'pclass',
 'sex',
 'fare',
 'embarked',
 'class',
 'who',
 'adult_male',
 'deck',
 'embark_town',
 'alive',
 'alone']

for variavel in qualitative_vars:
    valores_unicos = df1[variavel].unique()
    for valor in valores_unicos:
        print(f"{variavel} - {valor}")
        subamostra = df[df[variavel] == valor]
        display(subamostra.describe())
        print("="*100)
# Out:
# survived - 0
#        survived      pclass         age       sibsp       parch        fare
# count     549.0  549.000000  424.000000  549.000000  549.000000  549.000000
# mean        0.0    2.531876   30.626179    0.553734    0.329690   22.117887
# std         0.0    0.735805   14.172110    1.288399    0.823166   31.388207
# min         0.0    1.000000    1.000000    0.000000    0.000000    0.000000
# 25%         0.0    2.000000   21.000000    0.000000    0.000000    7.854200
# 50%         0.0    3.000000   28.000000    0.000000    0.000000   10.500000
# 75%         0.0    3.000000   39.000000    1.000000    0.000000   26.000000
# max         0.0    3.000000   74.000000    8.000000    6.000000  263.000000
# ...
# survived - 1
#        survived      pclass         age       sibsp       parch        fare
# count     342.0  342.000000  290.000000  342.000000  342.000000  342.000000
# mean        1.0    1.950292   28.343690    0.473684    0.464912   48.395408
# ...
